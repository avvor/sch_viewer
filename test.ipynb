# %%
from sch_viewer import *
parser = tNavigatorModelParser()
mod = []
mod.append(parser.build_model('C:/WORK/tNav/tNav_models/initial_model_full/initial_model/NETWORK_DEMO.DATA'))
mod.append(parser.build_model('C:/WORK/tNav/tNav_models/model0/Var1/VAR1.DATA'))
mod.append(parser.build_model('C:/WORK/tNav/tNav_models/Proj_TuronFeb22/predict.data'))
mod.append(parser.build_model('C:/WORK/tNav/tNav_models/SpeedTestModel/MODEL.DATA'))
mod.append(parser.build_model('C:/WORK/tNav/tNav_models/test_model/NETWORK_DEMO.DATA'))
mod.append(parser.build_model('I:/GDYA/Ach/ГДМ_АН-Ач_01.09/ACHIM_FULL/ACHIM_FULL/FULL/2021_01_24_HIST_2021_01_DETSR_2021/HIST_01.09.2022.DATA'))

# %%
from os import path
mod[3].save()

# %%
numbers1 = ['1', '2', '3', '4', '5']
numbers2 = list(['2', '1', '3', '4', '5'])
if numbers1 == numbers2:
    print("numbers1 equal to numbers2")
else:
    print("numbers1 is not equal to numbers2")

# %%
from sch_viewer import *
parser = tNavigatorModelParser()
model=parser.build_model('I:/GDYA/Ach/ГДМ_АН-Ач_01.09/ACHIM_FULL/ACHIM_FULL/FULL/2021_01_24_HIST_2021_01_DETSR_2021/HIST_01.09.2022.DATA')
# Out:
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A082_staby_2015.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A083.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A091.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A093.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A094.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A095.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A122.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A123.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A124.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A131.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A132.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A133.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A312_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A212_itog.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A313_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A321_stabb.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A322_Mody_Stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A323_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A391_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A142_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A143_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A314_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A351_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A352_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A011_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A012_copy_tran.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A023_1_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A024_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A031.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A032_Poetity_Stability.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A033.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A041.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A042.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A043.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A044.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A045.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A046.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A071_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A072_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A073_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A091.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A092.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A093_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A094.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A095.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A096.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A131_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A132_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A133_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A134_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A151_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A152_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A153_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A181.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A182.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A183.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A201.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A202.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A203.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A204.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A231.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A232.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A233.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A234.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A241_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A243_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/const.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A245_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A271_stan_euv.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A282_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A124_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A122_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A121_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A246_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A145.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A123_2017.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A141_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A142_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A143_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A144_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A301_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A283_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A272_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A273_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A302_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A303_2017_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A304_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A146.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A172.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A173.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A175.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A192.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A194.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A195.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/2020_01/1A071_no_wwr.vfp добавлена 2 раз(а)

# %%
model.read_from_excel('C:\\WORK\\tNav\\HIST_01.09.2022.xlsx')
# Out:
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A082_staby_2015.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A083.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A091.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A093.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A094.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A095.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A122.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A123.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A124.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A131.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A132.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A133.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A312_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A212_itog.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A313_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A321_stabb.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A322_Mody_Stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A323_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A391_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A142_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A143_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A314_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A351_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/2A/2A352_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A011_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A012_copy_tran.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A023_1_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A024_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A031.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A032_Poetity_Stability.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A033.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A041.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A042.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A043.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A044.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A045.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A046.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A071_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A072_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A073_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A091.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A092.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A093_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A094.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A095.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A096.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A131_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A132_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A133_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A134_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A151_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A152_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A153_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A181.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A182.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A183.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A201.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A202.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A203.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A204.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A231.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A232.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A233.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A234.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A241_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A243_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/const.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A245_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A271_stan_euv.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A282_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A124_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A122_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A121_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A246_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A145.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A123_2017.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A141_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A142_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A143_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A144_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A301_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A283_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A272_Staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A273_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A302_staby.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A303_2017_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A304_stab.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A146.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A172.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A173.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A175.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A192.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A194.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/1A195.vfp добавлена 2 раз(а)
# INCLUDE со ссылкой на файл ../INC/VFP/1A/2020_01/1A071_no_wwr.vfp добавлена 2 раз(а)
